# %% [markdown]
# <a href="https://colab.research.google.com/github/qcjscalma/CPE310-IE22S1/blob/main/%5BCALMA%5D_Exercise_1_2_Functions%2C_Loops%2C_and_iterations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exercise 1.2 Functions, Loops, and iterations**
#
#
#
# ---
#
#
# **Name:** Calma, Christian John S.  <br>
# **Section:** IE22S1 <br>
# **Date Submitted:** 1/22/2026 <br>
#
#
#
#
# ---

# %% [markdown]
# ## **Part 1: Functions**

# %% [markdown]
# **Exercise 1: What is the purpose of the “def” keyword in Python?**
# <br>
# a) It is slang that means “the following code is really cool”
# <br>
# b) It indicates the start of a function
# <br>
# c) It indicates that the following indented section of code is to be stored for later
# <br>
# d) b and c are both true
# <br>
# e) None of the above

# %% [markdown]
# **Answer: D**

# %% [markdown]
# **Exercise 2: What will the following Python program print out?**
#
# a) Zap ABC jane fred jane <br>
# b) Zap ABC Zap <br>
# c) ABC Zap jane <br>
# d) ABC Zap ABC <br>
# e) Zap Zap Zap <br>

# %%
def fred():
   print("Zap")

def jane():
   print("ABC")

jane()
fred()
jane()
# Out:
# ABC
# Zap
# ABC

# %% [markdown]
# **Answer: D**

# %% [markdown]
# **Exercise 3:** Rewrite your pay computation with time-and-a-half for overtime and create a function called `computepay` which takes two parameters (`hours` and `rate`).

# %% [markdown]
# ```
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0
# ```

# %%
#answer here

def computepay(hours, rate):
  if hours<=40:
    pay = (hours*rate)
  else:
    overtime = hours - 40
    pay = (40 * rate) + (overtime * rate*1.5)
    return pay
hours = int(input("Enter Hours: "))
rate = float (input("Enter Rate: "))
pay = computepay(hours, rate)
print("Pay:", pay)
# Out:
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0

# %% [markdown]
# **Exercise 4:** Rewrite the grade program from the previous chapter using a function called `computegrade` that takes a score as its parameter and returns a grade as a string.

# %% [markdown]
# ```
#   Score   Grade
# >= 0.9     A
# >= 0.8     B
# >= 0.7     C
# >= 0.6     D
#  < 0.6     F
# Enter score: 0.95
# A
# Enter score: perfect
# Bad score
# Enter score: 10.0
# Bad score
# Enter score: 0.75
# C
# Enter score: 0.5
# F ```

# %%
def computegrade(score):
  try:
    if grade_score >= 0.90:
      print("A")
    elif score >= .80:
      print("B")
    elif score >= .70:
      print("C")
    elif score >= 0.60:
      print("D")
    else:
      print("F")
  except:
    print('Bad score')

grade_score = float(input("Enter score: "))
computegrade(grade_score)
# Out:
# Enter score: 0.90
# A

# %%
def computegrade(score):
  try:
    if grade_score >= 0.90:
      print("A")
    elif score >= .80:
      print("B")
    elif score >= .70:
      print("C")
    elif score >= 0.60:
      print("D")
    else:
      print("F")
  except:
    print('Bad score')

grade_score = float(input("Enter score: "))
computegrade(grade_score)
# Out:
# Enter score: .80
# B

# %%
def computegrade(score):
  try:
    if grade_score >= 0.90:
      print("A")
    elif score >= .80:
      print("B")
    elif score >= .70:
      print("C")
    elif score >= 0.60:
      print("D")
    else:
      print("F")
  except:
    print('Bad score')

grade_score = float(input("Enter score: "))
computegrade(grade_score)
# Out:
# Enter score: .70
# C

# %%
def computegrade(score):
  try:
    if grade_score >= 0.90:
      print("A")
    elif score >= .80:
      print("B")
    elif score >= .70:
      print("C")
    elif score >= 0.60:
      print("D")
    else:
      print("F")
  except:
    print('Bad score')

grade_score = float(input("Enter score: "))
computegrade(grade_score)
# Out:
# Enter score: .60
# D

# %%
def computegrade(score):
  try:
    if grade_score >= 0.90:
      print("A")
    elif score >= .80:
      print("B")
    elif score >= .70:
      print("C")
    elif score >= 0.60:
      print("D")
    else:
      print("F")
  except:
    print('Bad score')

grade_score = float(input("Enter score: "))
computegrade(grade_score)
# Out:
# Enter score: .5
# F

# %% [markdown]
# ## **Part 2: Loops and Iterations**

# %% [markdown]
# **Exercise 1:** Write a program which repeatedly reads integers until the user enters “done”. Once “done” is entered, print out the total, count, and average of the integers. If the user enters anything other than a integers, detect their mistake using try and except and print an error message and skip to the next integers.

# %%
total = 0
count = 0
try:
  num = int(input("Enter a number: "))
  while num != "done":
    total = total + int(num)
    count = count + 1
    num = input("Enter a number: ")
except:
  print("Invalid input, please insert whole numbers only.")
  print(f"total: {total}\nCount: {count}\nAverage: {total/count}")
# Out:
# Enter a number: 1
# Enter a number: 2
# Enter a number: 3
# Enter a number: 4
# Enter a number: 5
# Enter a number: 6
# Enter a number: 7
# Enter a number: 8
# Enter a number: 9
# Enter a number: 10
# Enter a number: Done
# Invalid input, please insert whole numbers only.
# total: 55
# Count: 10
# Average: 5.5

# %% [markdown]
# **Exercise 2:** Write another program that prompts for a list of numbers as above and at the end prints out both the maximum and minimum of the numbers instead of the average.

# %%
largest = None
smallest = None

while True:
  inp = input("Enter a number: ")
  if inp == "done":
    break

  try:
    num = int(inp)

  except:
    print("invalid output")
    continue

  if largest is None or num > largest:
        largest = num

  if smallest is None or num < smallest:
        smallest = num

print("Maximum:", largest)
print("Minimum", smallest)
# Out:
# Enter a number: 1
# Enter a number: 2
# Enter a number: 3
# Enter a number: 4
# Enter a number: 5
# Enter a number: 6
# Enter a number: 7
# Enter a number: 8
# Enter a number: 9
# Enter a number: 10
# Enter a number: done
# Maximum: 10
# Minimum 1

# %%
largest = None
smallest = None

while True:
  inp = input("Enter a number: ")
  if inp == "done":
    break

  try:
    num = int(inp)

  except:
    print("invalid output")
    continue

  if largest is None or num > largest:
        largest = num

  if smallest is None or num < smallest:
        smallest = num

print("Maximum:", largest)
print("Minimum", smallest)
# Out:
# Enter a number: 10
# Enter a number: 9
# Enter a number: 8
# Enter a number: 7.67
# invalid output
# Enter a number: 6
# Enter a number: 5
# Enter a number: 4
# Enter a number: 3
# Enter a number: 21
# Enter a number: 0
# Enter a number: done
# Maximum: 21
# Minimum 0
